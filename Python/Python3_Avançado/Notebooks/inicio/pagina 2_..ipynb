# %% [markdown]
# Qualquer coisa guardada no input() é string, não adianta ...

# %%
entrada = input('que timemeteu? ')
# Out:
# que timemeteu? hulk

# %%
print(f'O {entrada} foi quem timeteu, \nE o tipo dele é 'f'{type(entrada)}')
# Out:
# O o kid bengala  foi quem timeteu,
# E o tipo dele é <class 'str'>

# %%
e = input('digite 0 para False e 1 para True: ')

saida = bool(e) 

saida # qualquer string diferente de '' é true na conversão em bool
# Out:
# digite 0 para False e 1 para True:
# False

# %% [markdown]
# Converte a entrada em inteiro que dá bom...

# %%
entrada2 = input("qunatos rins vc tem ? ")
# Out:
# qunatos rins vc tem ? 35

# %%
soma= float(entrada2) + 2 
print(f'a soma de seus rins mais 2 é {soma:.5f}')
# Out:
# a soma de seus rins mais 2 é 37.00000

# %% [markdown]
# Ou converte já na entrada pra ficar melhor !

# %%
numero = float(input("digite um nuemro ai ! ")) # fazendo o cast já na entrada 
print(f'{type(numero)}')
# Out:
# digite um nuemro ai ! 2
# <class 'float'>

# %%
print(type(numero))
# Out:
# <class 'float'>

# %% [markdown]
# Em programação, os termos "fazer cast" ou "type cast" referem-se à conversão de um tipo de valor em outro tipo de valor.
