# %%
# iterando sobre string 
# valores que possuem índice chamam-se Iteráveis

# %%
frase = 'a carne mais barata do mercado é a carne negra'

x = len(frase)
print(f'a dimensão da frase é : {x}')
# Out:
# a dimensão da frase é : 46

# %%
frase = 'a carne mais barata do mercado é a carne negra' 
new_frase = ''
c = 0
while c < len(frase): 

  if frase[c] == ' ':
    new_frase += '_'
    c += 1 
    continue 
  new_frase += frase[c] 
  print(new_frase)
  c += 1
# Out:
# a
# a_c
# a_ca
# a_car
# a_carn
# a_carne
# a_carne_m
# a_carne_ma
# a_carne_mai
# a_carne_mais
# a_carne_mais_b
# a_carne_mais_ba
# a_carne_mais_bar
# a_carne_mais_bara
# a_carne_mais_barat
# a_carne_mais_barata
# a_carne_mais_barata_d
# a_carne_mais_barata_do
# a_carne_mais_barata_do_m
# a_carne_mais_barata_do_me
# a_carne_mais_barata_do_mer
# a_carne_mais_barata_do_merc
# a_carne_mais_barata_do_merca
# a_carne_mais_barata_do_mercad
# a_carne_mais_barata_do_mercado
# a_carne_mais_barata_do_mercado_é
# a_carne_mais_barata_do_mercado_é_a
# a_carne_mais_barata_do_mercado_é_a_c
# a_carne_mais_barata_do_mercado_é_a_ca
# a_carne_mais_barata_do_mercado_é_a_car
# a_carne_mais_barata_do_mercado_é_a_carn
# a_carne_mais_barata_do_mercado_é_a_carne
# a_carne_mais_barata_do_mercado_é_a_carne_n
# a_carne_mais_barata_do_mercado_é_a_carne_ne
# a_carne_mais_barata_do_mercado_é_a_carne_neg
# a_carne_mais_barata_do_mercado_é_a_carne_negr
# a_carne_mais_barata_do_mercado_é_a_carne_negra

# %%
frase = 'a carne mais barata do mercado é a carne negra' 
y = '' 

x = input('digite uma letra: ')

c = 0 
try:
  while c < len(frase): 
    if frase[c] == x :
      y += frase[c].upper() 
      c += 1
      print(y)
      continue
    y += frase[c] 
    c += 1
    print(y)
except:
  print('ERROR: vc digitou caractere não válido.')
# Out:
# digite uma letra: a
# A
# A
# A c
# A cA
# A cAr
# A cArn
# A cArne
# A cArne
# A cArne m
# A cArne mA
# A cArne mAi
# A cArne mAis
# A cArne mAis
# A cArne mAis b
# A cArne mAis bA
# A cArne mAis bAr
# A cArne mAis bArA
# A cArne mAis bArAt
# A cArne mAis bArAtA
# A cArne mAis bArAtA
# A cArne mAis bArAtA d
# A cArne mAis bArAtA do
# A cArne mAis bArAtA do
# A cArne mAis bArAtA do m
# A cArne mAis bArAtA do me
# A cArne mAis bArAtA do mer
# A cArne mAis bArAtA do merc
# A cArne mAis bArAtA do mercA
# A cArne mAis bArAtA do mercAd
# A cArne mAis bArAtA do mercAdo
# A cArne mAis bArAtA do mercAdo
# A cArne mAis bArAtA do mercAdo é
# A cArne mAis bArAtA do mercAdo é
# A cArne mAis bArAtA do mercAdo é A
# A cArne mAis bArAtA do mercAdo é A
# A cArne mAis bArAtA do mercAdo é A c
# A cArne mAis bArAtA do mercAdo é A cA
# A cArne mAis bArAtA do mercAdo é A cAr
# A cArne mAis bArAtA do mercAdo é A cArn
# A cArne mAis bArAtA do mercAdo é A cArne
# A cArne mAis bArAtA do mercAdo é A cArne
# ...

# %%
# laço while : não sabemos exatamente o nuemro de iterações 
# laço for: sabemos o nuemro de iterações 

frase = 'atirei o pau no gato'

for i,letra in enumerate(frase):
  print(i,letra)
# Out:
# 0 a
# 1 t
# 2 i
# 3 r
# 4 e
# 5 i
# 6
# 7 o
# 8
# 9 p
# 10 a
# 11 u
# 12
# 13 n
# 14 o
# 15
# 16 g
# 17 a
# 18 t
# 19 o

# %%
for i in range(0,5,1):
  #(começo,fim-1,passo)
  print(i)
# Out:
# 0
# 1
# 2
# 3
# 4

# %%
for i in range(10,5,-1):
  #(começo,fim-1,passo) , decrementando
  print(i)
# Out:
# 10
# 9
# 8
# 7
# 6

# %%
frase = 'atirei o pau no gato'
n_frase = ''

for i in frase:
  if i == 'a':
    n_frase += i.upper()
  else:
    n_frase += i

print(n_frase)

# continue e break funcionam da mesma forma no for
# Out:
# Atirei o pAu no gAto
